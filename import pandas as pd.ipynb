# %% [markdown]
# Connected to Python 3.12.7

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\TUF\Desktop\text.csv")
print(df.head())
len(df)
# Out:
#    OrderID CustomerID ProductCategory   Price  Quantity   OrderDate  Shipped
# 0     1001       C101     Electronics  499.99         1  2025-10-15     True
# 1     1002       C102           Books   19.99         2  2025-10-15     True
# 2     1003       C101         Apparel   45.00         3  2025-10-16     True
# 3     1004       C103     Electronics  129.50         1  2025-10-16    False
# 4     1005       C104           Books   12.00         5  2025-10-17     True
# 8

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\TUF\Desktop\text.csv")
print(df.head())
len(df)
df.columns
# Out:
#    OrderID CustomerID ProductCategory   Price  Quantity   OrderDate  Shipped
# 0     1001       C101     Electronics  499.99         1  2025-10-15     True
# 1     1002       C102           Books   19.99         2  2025-10-15     True
# 2     1003       C101         Apparel   45.00         3  2025-10-16     True
# 3     1004       C103     Electronics  129.50         1  2025-10-16    False
# 4     1005       C104           Books   12.00         5  2025-10-17     True
# Index(['OrderID', 'CustomerID', 'ProductCategory', 'Price', 'Quantity',
#        'OrderDate', 'Shipped'],
#       dtype='object')

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\TUF\Desktop\text.csv")
print(df.head())
len(df)
df.columns
df[df['Price']>20]
# Out:
#    OrderID CustomerID ProductCategory   Price  Quantity   OrderDate  Shipped
# 0     1001       C101     Electronics  499.99         1  2025-10-15     True
# 1     1002       C102           Books   19.99         2  2025-10-15     True
# 2     1003       C101         Apparel   45.00         3  2025-10-16     True
# 3     1004       C103     Electronics  129.50         1  2025-10-16    False
# 4     1005       C104           Books   12.00         5  2025-10-17     True
#    OrderID CustomerID ProductCategory    Price  Quantity   OrderDate  Shipped
# 0     1001       C101     Electronics   499.99         1  2025-10-15     True
# 2     1003       C101         Apparel    45.00         3  2025-10-16     True
# 3     1004       C103     Electronics   129.50         1  2025-10-16    False
# 5     1006       C102         Apparel    75.00         1  2025-10-17    False
# 6     1007       C101     Electronics  1200.00         1  2025-10-18     True
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\TUF\Desktop\text.csv")
print(df.head())
len(df)
df.columns
df[df['Price']>20]
df.tail()
# Out:
#    OrderID CustomerID ProductCategory   Price  Quantity   OrderDate  Shipped
# 0     1001       C101     Electronics  499.99         1  2025-10-15     True
# 1     1002       C102           Books   19.99         2  2025-10-15     True
# 2     1003       C101         Apparel   45.00         3  2025-10-16     True
# 3     1004       C103     Electronics  129.50         1  2025-10-16    False
# 4     1005       C104           Books   12.00         5  2025-10-17     True
#    OrderID CustomerID ProductCategory    Price  Quantity   OrderDate  Shipped
# 3     1004       C103     Electronics   129.50         1  2025-10-16    False
# 4     1005       C104           Books    12.00         5  2025-10-17     True
# 5     1006       C102         Apparel    75.00         1  2025-10-17    False
# 6     1007       C101     Electronics  1200.00         1  2025-10-18     True
# 7     1008       C105         Apparel    25.99         4  2025-10-18     True

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\TUF\Desktop\text.csv")
print(df.head())
len(df)
df.columns
df[df['Price']>20]
df.tail()
df['Price']>20
# Out:
#    OrderID CustomerID ProductCategory   Price  Quantity   OrderDate  Shipped
# 0     1001       C101     Electronics  499.99         1  2025-10-15     True
# 1     1002       C102           Books   19.99         2  2025-10-15     True
# 2     1003       C101         Apparel   45.00         3  2025-10-16     True
# 3     1004       C103     Electronics  129.50         1  2025-10-16    False
# 4     1005       C104           Books   12.00         5  2025-10-17     True
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# 5     True
# 6     True
# 7     True
# Name: Price, dtype: bool

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\TUF\Desktop\text.csv")
print(df.head())
len(df)
df.columns
df[df['Price']>20]
df.tail()
df['Price']>20
df.count()
# Out:
#    OrderID CustomerID ProductCategory   Price  Quantity   OrderDate  Shipped
# 0     1001       C101     Electronics  499.99         1  2025-10-15     True
# 1     1002       C102           Books   19.99         2  2025-10-15     True
# 2     1003       C101         Apparel   45.00         3  2025-10-16     True
# 3     1004       C103     Electronics  129.50         1  2025-10-16    False
# 4     1005       C104           Books   12.00         5  2025-10-17     True
# OrderID            8
# CustomerID         8
# ProductCategory    8
# Price              8
# Quantity           8
# OrderDate          8
# Shipped            8
# dtype: int64

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\TUF\Desktop\text.csv")
print(df.head())
len(df)
df.columns
df[df['Price']>20]
df.tail()
df['Price']>20
df.count()
df['CustomerID']
# Out:
#    OrderID CustomerID ProductCategory   Price  Quantity   OrderDate  Shipped
# 0     1001       C101     Electronics  499.99         1  2025-10-15     True
# 1     1002       C102           Books   19.99         2  2025-10-15     True
# 2     1003       C101         Apparel   45.00         3  2025-10-16     True
# 3     1004       C103     Electronics  129.50         1  2025-10-16    False
# 4     1005       C104           Books   12.00         5  2025-10-17     True
# 0    C101
# 1    C102
# 2    C101
# 3    C103
# 4    C104
# 5    C102
# 6    C101
# 7    C105
# Name: CustomerID, dtype: object

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\TUF\Desktop\text.csv")
print(df.head())
len(df)
df.columns
df[df['Price']>20]
df.tail()
df['Price']>20
df.count()
df['CustomerID'].count()
# Out:
#    OrderID CustomerID ProductCategory   Price  Quantity   OrderDate  Shipped
# 0     1001       C101     Electronics  499.99         1  2025-10-15     True
# 1     1002       C102           Books   19.99         2  2025-10-15     True
# 2     1003       C101         Apparel   45.00         3  2025-10-16     True
# 3     1004       C103     Electronics  129.50         1  2025-10-16    False
# 4     1005       C104           Books   12.00         5  2025-10-17     True
# np.int64(8)

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\TUF\Desktop\text.csv")
print(df.head())
len(df)
df.columns
df[df['Price']>20]
df.tail()
df['Price']>20
df.count()
df['CustomerID'].count()
new_df=df[(df['Price']>30) & (df['Quantity']>1)]
# Out:
#    OrderID CustomerID ProductCategory   Price  Quantity   OrderDate  Shipped
# 0     1001       C101     Electronics  499.99         1  2025-10-15     True
# 1     1002       C102           Books   19.99         2  2025-10-15     True
# 2     1003       C101         Apparel   45.00         3  2025-10-16     True
# 3     1004       C103     Electronics  129.50         1  2025-10-16    False
# 4     1005       C104           Books   12.00         5  2025-10-17     True

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\TUF\Desktop\text.csv")
print(df.head())
len(df)
df.columns
df[df['Price']>20]
df.tail()
df['Price']>20
df.count()
df['CustomerID'].count()
new_df=df[(df['Price']>30) & (df['Quantity']>1)]
print(new_df)
# Out:
#    OrderID CustomerID ProductCategory   Price  Quantity   OrderDate  Shipped
# 0     1001       C101     Electronics  499.99         1  2025-10-15     True
# 1     1002       C102           Books   19.99         2  2025-10-15     True
# 2     1003       C101         Apparel   45.00         3  2025-10-16     True
# 3     1004       C103     Electronics  129.50         1  2025-10-16    False
# 4     1005       C104           Books   12.00         5  2025-10-17     True
#    OrderID CustomerID ProductCategory  Price  Quantity   OrderDate  Shipped
# 2     1003       C101         Apparel   45.0         3  2025-10-16     True

# %%
new_df=df[(df['Price']>30) & (df['Quantity']>1)]

# %%
print(new_df)
# Out:
#    OrderID CustomerID ProductCategory  Price  Quantity   OrderDate  Shipped
# 2     1003       C101         Apparel   45.0         3  2025-10-16     True

# %%
df.describe()
# Out:
#           OrderID        Price  Quantity
# count     8.00000     8.000000  8.000000
# mean   1004.50000   250.933750  2.250000
# std       2.44949   416.085045  1.581139
# min    1001.00000    12.000000  1.000000
# 25%    1002.75000    24.490000  1.000000
# 50%    1004.50000    60.000000  1.500000
# 75%    1006.25000   222.122500  3.250000
# max    1008.00000  1200.000000  5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderID          8 non-null      int64
#  1   CustomerID       8 non-null      object
#  2   ProductCategory  8 non-null      object
#  3   Price            8 non-null      float64
#  4   Quantity         8 non-null      int64
#  5   OrderDate        8 non-null      object
#  6   Shipped          8 non-null      bool
# dtypes: bool(1), float64(1), int64(2), object(3)
# memory usage: 524.0+ bytes

# %%
df
# Out:
#    OrderID CustomerID ProductCategory    Price  Quantity   OrderDate  Shipped
# 0     1001       C101     Electronics   499.99         1  2025-10-15     True
# 1     1002       C102           Books    19.99         2  2025-10-15     True
# 2     1003       C101         Apparel    45.00         3  2025-10-16     True
# 3     1004       C103     Electronics   129.50         1  2025-10-16    False
# 4     1005       C104           Books    12.00         5  2025-10-17     True
# 5     1006       C102         Apparel    75.00         1  2025-10-17    False
# 6     1007       C101     Electronics  1200.00         1  2025-10-18     True
# 7     1008       C105         Apparel    25.99         4  2025-10-18     True

# %%
df['new'] = df['OrderID'].astype(str) + '-' + df['CustomerID']

# %%
df
# Out:
#    OrderID CustomerID ProductCategory    Price  Quantity   OrderDate  Shipped  \
# 0     1001       C101     Electronics   499.99         1  2025-10-15     True
# 1     1002       C102           Books    19.99         2  2025-10-15     True
# 2     1003       C101         Apparel    45.00         3  2025-10-16     True
# 3     1004       C103     Electronics   129.50         1  2025-10-16    False
# 4     1005       C104           Books    12.00         5  2025-10-17     True
# 5     1006       C102         Apparel    75.00         1  2025-10-17    False
# 6     1007       C101     Electronics  1200.00         1  2025-10-18     True
# 7     1008       C105         Apparel    25.99         4  2025-10-18     True
#
#          new
# 0  1001-C101
# 1  1002-C102
# 2  1003-C101
# 3  1004-C103
# 4  1005-C104
# 5  1006-C102
# 6  1007-C101
# 7  1008-C105

# %%
df['zarb']=df['Price']*df['Quantity']

# %%
df
# Out:
#    OrderID CustomerID ProductCategory    Price  Quantity   OrderDate  Shipped  \
# 0     1001       C101     Electronics   499.99         1  2025-10-15     True
# 1     1002       C102           Books    19.99         2  2025-10-15     True
# 2     1003       C101         Apparel    45.00         3  2025-10-16     True
# 3     1004       C103     Electronics   129.50         1  2025-10-16    False
# 4     1005       C104           Books    12.00         5  2025-10-17     True
# 5     1006       C102         Apparel    75.00         1  2025-10-17    False
# 6     1007       C101     Electronics  1200.00         1  2025-10-18     True
# 7     1008       C105         Apparel    25.99         4  2025-10-18     True
#
#          new     zarb
# 0  1001-C101   499.99
# 1  1002-C102    39.98
# 2  1003-C101   135.00
# 3  1004-C103   129.50
# 4  1005-C104    60.00
# 5  1006-C102    75.00
# 6  1007-C101  1200.00
# 7  1008-C105   103.96

# %%
df['zarb']
# Out:
# 0     499.99
# 1      39.98
# 2     135.00
# 3     129.50
# 4      60.00
# 5      75.00
# 6    1200.00
# 7     103.96
# Name: zarb, dtype: float64

# %%
df['Shipped']
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5    False
# 6     True
# 7     True
# Name: Shipped, dtype: bool

# %%
df['Shipped'].unique()
# Out:
# array([ True, False])

# %%
df['Shipped'].value_counts()
# Out:
# Shipped
# True     6
# False    2
# Name: count, dtype: int64

# %%
df.groupby('Shipped')['Price'].mean()
# Out:
# Shipped
# False    102.250
# True     300.495
# Name: Price, dtype: float64

# %%
df.groupby('Shipped')['Price'].aggregate(lambda x:x.sum() / len(x))
# Out:
# Shipped
# False    102.250
# True     300.495
# Name: Price, dtype: float64

# %%
import matplotlib.pyplot

# %%
data=pd.read_csv(r"C:\Users\TUF\Desktop\machine learning\titanic.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
data['Age'].hist()
# Out:
# <Axes: >

# %%
data.plot.line(x='Age',y='Pclass')
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# No kernel connected

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data
#
# NameError: name 'data' is not defined
